# %% [markdown]
# Q-1. Write an SQL query to print the FIRST_NAME from Worker table after replacing ‘a’
# with ‘A’.

# %% [markdown]
# SELECT REPLACE(first_name, "a", "A") FROM worker;

# %% [markdown]
# ![Screenshot%202022-12-08%20144636.jpg](attachment:Screenshot%202022-12-08%20144636.jpg)

# %% [markdown]
# Q-2. Write an SQL query to print all Worker details from the Worker table order by
# FIRST_NAME Ascending and DEPARTMENT Descending.

# %% [markdown]
# ![Screenshot%202022-12-08%20145031.jpg](attachment:Screenshot%202022-12-08%20145031.jpg)

# %% [markdown]
# Q-3. Write an SQL query to fetch the names of workers who earn the highest salary.

# %% [markdown]
# ![Screenshot%202022-12-08%20145416.jpg](attachment:Screenshot%202022-12-08%20145416.jpg)
