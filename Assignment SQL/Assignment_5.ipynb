# %% [markdown]
# Q-1. Write an SQL query to print details of workers excluding first names, “Vipul” and
# “Satish” from Worker table.

# %% [markdown]
# Select * from Worker where FIRST_NAME not in ('Vipul','Satish');

# %% [markdown]
# ![Screenshot%202022-12-08%20145858.jpg](attachment:Screenshot%202022-12-08%20145858.jpg)

# %% [markdown]
# Q-2. Write an SQL query to print details of the Workers whose FIRST_NAME ends with
# ‘h’ and contains six alphabets.

# %% [markdown]
# Select * from Worker where FIRST_NAME like '_____h';

# %% [markdown]
# ![Screenshot%202022-12-08%20150050.jpg](attachment:Screenshot%202022-12-08%20150050.jpg)

# %% [markdown]
# Q-3. Write a query to validate Email of Employee.

# %% [markdown]
# SELECT * FROM worker WHERE emailid NOT LIKE '[0-9a-zA-Z]%@%.%'

# %% [markdown]
# ![Screenshot%202022-12-08%20150213.jpg](attachment:Screenshot%202022-12-08%20150213.jpg)
