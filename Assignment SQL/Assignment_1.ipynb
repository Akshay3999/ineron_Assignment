# %% [markdown]
# # Q-1. Write an SQL query to fetch “FIRST_NAME” from Worker table using the alias name as &lt;WORKER_NAME&gt;.

# %% [markdown]
# ![Screenshot%202022-10-02%20205540.jpg](attachment:Screenshot%202022-10-02%20205540.jpg)

# %% [markdown]
# # 2. Write an SQL query to fetch unique values of DEPARTMENT from Worker table.

# %% [markdown]
# ![Screenshot%202022-10-02%20210924.jpg](attachment:Screenshot%202022-10-02%20210924.jpg)

# %% [markdown]
# # 3. Write an SQL query to show the last 5 record from a table.

# %% [markdown]
# ![Screenshot%202022-10-02%20211515.jpg](attachment:Screenshot%202022-10-02%20211515.jpg)
