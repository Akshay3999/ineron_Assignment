# %% [markdown]
# # Q-1. Write an SQL query to print the first three characters of  FIRST_NAME from Worker table.

# %% [markdown]
# ![Screenshot%202022-10-03%20153749.jpg](attachment:Screenshot%202022-10-03%20153749.jpg)

# %% [markdown]
# # Q-2. Write an SQL query to find the position of the alphabet (‘a’) in the first name column ‘Amitabh’ from Worker table.

# %% [markdown]
# ![Screenshot%202022-10-03%20203519.jpg](attachment:Screenshot%202022-10-03%20203519.jpg)

# %% [markdown]
# # Q-3. Write an SQL query to print the name of employees having the highest salary in each department.

# %% [markdown]
# ![Screenshot%202022-10-03%20204245.jpg](attachment:Screenshot%202022-10-03%20204245.jpg)
