# %% [markdown]
# # Q-1. Write an SQL query to print the FIRST_NAME from Worker table after removing white spaces from the right side.

# %% [markdown]
# ![Screenshot%202022-11-11%20221940.jpg](attachment:Screenshot%202022-11-11%20221940.jpg)

# %% [markdown]
# # Q-2. Write an SQL query that fetches the unique values of DEPARTMENT from Worker table and prints its length.

# %% [markdown]
# ![Screenshot%202022-11-11%20223545.jpg](attachment:Screenshot%202022-11-11%20223545.jpg)

# %% [markdown]
# # Q-3. Write an SQL query to fetch nth max salaries from a table.

# %% [markdown]
# SELECT Salary FROM Worker ORDER BY Salary DESC LIMIT 5,1;
#
# where n = 5
#
# OR
#
# SELECT SAL FROM( SELECT ROWNUM SLNO,SAL FROM (SELECT DISTINCT SAL FROM EMP ORDER BY SAL DESC)) WHERE SLNO=5;

# %% [markdown]
# ![image.png](attachment:image.png)
